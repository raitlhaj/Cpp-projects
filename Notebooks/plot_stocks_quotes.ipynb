# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from underlyings.stock import Stock

# %matplotlib inline
s = Stock('AAPL')
start_date = pd.to_datetime('2020-01-01')
end_date = pd.to_datetime('2022-01-01')
apple = s.get_quotes(start_date, end_date)
apple.plot(legend = True, grid = True)
# Out:
# <AxesSubplot: >

# %%
from underlyings.index import Index

start_date = "01/01/2023" #pd.to_datetime('2020-01-01')
end_date = "03/03/2023" 
val = Index("SPX")
df = val.get_quotes(start_date, end_date)
df.plot(legend = True, grid = True)
# Out:
# <AxesSubplot: >
